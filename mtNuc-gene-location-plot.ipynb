# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.ticker as ticker

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
nucMit = pd.read_csv("Locations_of_mito_genes.txt", sep="\t")
nucMit
# Out:
#              GENE_ID            CHR     START       END  \
# 0    TCALIF_01361-PA   Chromosome_1  10195875  10204688
# 1    TCALIF_01397-PA   Chromosome_1  10570799  10575186
# 2    TCALIF_01417-PA   Chromosome_1  10796329  10800027
# 3    TCALIF_02460-PA   Chromosome_1   1388597   1390475
# 4    TCALIF_02461-PA   Chromosome_1   1366917   1384425
# ..               ...            ...       ...       ...
# 594  TCALIF_11632-PA  Chromosome_12   9193274   9197467
# 595  TCALIF_11846-PA  Chromosome_12  18033445  18038227
# 596  TCALIF_11851-PA  Chromosome_12  17988309  17996651
# 597  TCALIF_12040-PA  Chromosome_12    272536    274602
# 598  TCALIF_13739-PA  Chromosome_12  12869187  12870663
#
#                                               GENENAME MITO_CATEGORY
# 0    Slc25a32 Mitochondrial folate transporter/carr...           NaN
# 1    Mccc2 Methylcrotonoyl-CoA carboxylase beta cha...           NaN
# 2    RPUSD2 RNA pseudouridylate synthase domain-con...           NaN
# 3    Roe1 GrpE protein homolog, mitochondrial (Dros...           NaN
# 4    Carkd ATP-dependent (S)-NAD(P)H-hydrate dehydr...           NaN
# ..                                                 ...           ...
# 594           HRSP12 Ribonuclease UK114 (Homo sapiens)           NaN
# 595  AASS Alpha-aminoadipic semialdehyde synthase, ...           NaN
# 596  NAD-dependent malic enzyme 59 kDa isoform, mit...           NaN
# 597  Cyp1 Peptidyl-prolyl cis-trans isomerase (Dros...           NaN
# 598  PNPT1 Polyribonucleotide nucleotidyltransferas...           NaN
#
# [599 rows x 6 columns]

# %%
nucMit[nucMit["CHR"]=="Chromosome_1"]
# Out:
#             GENE_ID           CHR     START       END  \
# 11  TCALIF_03216-PA  Chromosome_1  12748443  12752979
# 13  TCALIF_03266-PA  Chromosome_1  15238434  15249519
# 25  TCALIF_04664-PA  Chromosome_1   1943286   1946340
# 28  TCALIF_06837-PA  Chromosome_1   8307631   8309423
# 39  TCALIF_10240-PA  Chromosome_1   3819166   3819369
#
#                                              GENENAME MITO_CATEGORY
# 11  cox12 Cytochrome c oxidase subunit 6B (Schizos...       Comp-IV
# 13  MRPL27 39S ribosomal protein L27, mitochondria...           mRP
# 25  mRpL45 Probable 39S ribosomal protein L45, mit...           mRP
# 28  NDUFA6 NADH dehydrogenase [ubiquinone] 1 alpha...        Comp-I
# 39  Cox6c Cytochrome c oxidase subunit 6C (Mus mus...       Comp-IV

# %%
nucMit[nucMit["CHR"]=="Chromosome_2"]
# Out:
#              GENE_ID           CHR     START       END  \
# 50   TCALIF_00531-PA  Chromosome_2   7516074   7517461
# 53   TCALIF_00587-PA  Chromosome_2   7900528   7902264
# 55   TCALIF_00605-PA  Chromosome_2   8093166   8094044
# 56   TCALIF_00647-PA  Chromosome_2   5671494   5672459
# 58   TCALIF_00652-PA  Chromosome_2   5653922   5654719
# 63   TCALIF_01282-PA  Chromosome_2  10088377  10092283
# 66   TCALIF_01599-PA  Chromosome_2   7242969   7244320
# 73   TCALIF_04583-PA  Chromosome_2  11311948  11312487
# 80   TCALIF_06330-PA  Chromosome_2  11947119  11949919
# 83   TCALIF_06393-PA  Chromosome_2  13236061  13237419
# 88   TCALIF_07035-PA  Chromosome_2   1437382   1438383
# 89   TCALIF_07109-PA  Chromosome_2  10621073  10623931
# 93   TCALIF_08370-PA  Chromosome_2  14253006  14254820
# 96   TCALIF_08385-PA  Chromosome_2  14148436  14152940
# 99   TCALIF_09188-PA  Chromosome_2  13576243  13584896
# 101  TCALIF_09514-PA  Chromosome_2   4397675   4398385
# 107  TCALIF_10088-PA  Chromosome_2   2083420   2091554
# 114  TCALIF_12586-PA  Chromosome_2   2424915   2425958
#
#                                               GENENAME MITO_CATEGORY
# 50   MRPL4 39S ribosomal protein L4, mitochondrial ...           mRP
# 53   MRPS31 28S ribosomal protein S31, mitochondria...           mRP
# 55   MRPL16 39S ribosomal protein L16, mitochondria...           mRP
# 56   mRpL19 39S ribosomal protein L19, mitochondria...           mRP
# 58   mRpL24 Probable 39S ribosomal protein L24, mit...           mRP
# 63   Mrpl38 39S ribosomal protein L38, mitochondria...           mRP
# 66   bonsai 28S ribosomal protein S15, mitochondria...           mRP
# 73   MRPS23 28S ribosomal protein S23, mitochondria...           mRP
# 80   SARS2 Serine--tRNA ligase, mitochondrial (Bos ...         mtARS
# 83   D2030.4 NADH dehydrogenase [ubiquinone] 1 beta...        Comp-I
# 88   UQCR10 Cytochrome b-c1 complex subunit 9 (Bos ...      Comp-III
# 89   Nars2 Probable asparagine--tRNA ligase, mitoch...         mtARS
# 93   NDUFV2 NADH dehydrogenase [ubiquinone] flavopr...        Comp-I
# 96   MRPS21 28S ribosomal protein S21, mitochondria...           mRP
# 99             Vars Valine--tRNA ligase (Mus musculus)         mtARS
# 101  mRpS7 28S ribosomal protein S7, mitochondrial ...           mRP
# 107  mRpL55 39S ribosomal protein L55, mitochondria...           mRP
# 114  MRPL42 39S ribosomal protein L42, mitochondria...           mRP

# %%
nucMit["CHR"].nunique()
# Out:
# 12

# %%
# copied stats from https://www.ncbi.nlm.nih.gov/assembly/GCA_007210705.1#/st into file:
assembly_stats = pd.read_csv("tcalifornicus-genome-2.1.stats.csv")
assembly_stats
# Out:
#          Molecule  Total Length  Scaffold Count  Ungapped Length  \
# 0             All     191142546             459        187158573
# 1    Chromosome 1      16497411               1         16235956
# 2    Chromosome 2      15265986               1         14949834
# 3    Chromosome 3      14796774               1         14492897
# 4    Chromosome 4      13375517               1         13128394
# 5    Chromosome 5      16473687               1         16148074
# 6    Chromosome 6      15273878               1         14924583
# 7    Chromosome 7      16452659               1         16151402
# 8    Chromosome 8      15676443               1         15402154
# 9    Chromosome 9      15806032               1         15538449
# 10  Chromosome 10      16296148               1         16034734
# 11  Chromosome 11      15796145               1         15449980
# 12  Chromosome 12      18073795               1         17424573
# 13       unplaced       1358071             447          1277543
#
#     Scaffold N50  Spanned Gaps  Unspanned Gaps
# 0       15806032         10882               0
# 1       16497411           704               0
# 2       15265986           836               0
# 3       14796774           741               0
# 4       13375517           692               0
# 5       16473687           975               0
# 6       15273878           962               0
# 7       16452659           818               0
# 8       15676443           894               0
# 9       15806032           777               0
# 10      16296148           711               0
# 11      15796145           893               0
# 12      18073795          1248               0
# 13          7769           631               0

# %%
assembly_stats["Molecule"] = assembly_stats["Molecule"].str.replace(" ", "_")
c
# Out:
#          Molecule  Total Length  Scaffold Count  Ungapped Length  \
# 0             All     191142546             459        187158573
# 1    Chromosome_1      16497411               1         16235956
# 2    Chromosome_2      15265986               1         14949834
# 3    Chromosome_3      14796774               1         14492897
# 4    Chromosome_4      13375517               1         13128394
# 5    Chromosome_5      16473687               1         16148074
# 6    Chromosome_6      15273878               1         14924583
# 7    Chromosome_7      16452659               1         16151402
# 8    Chromosome_8      15676443               1         15402154
# 9    Chromosome_9      15806032               1         15538449
# 10  Chromosome_10      16296148               1         16034734
# 11  Chromosome_11      15796145               1         15449980
# 12  Chromosome_12      18073795               1         17424573
# 13       unplaced       1358071             447          1277543
#
#     Scaffold N50  Spanned Gaps  Unspanned Gaps
# 0       15806032         10882               0
# 1       16497411           704               0
# 2       15265986           836               0
# 3       14796774           741               0
# 4       13375517           692               0
# 5       16473687           975               0
# 6       15273878           962               0
# 7       16452659           818               0
# 8       15676443           894               0
# 9       15806032           777               0
# 10      16296148           711               0
# 11      15796145           893               0
# 12      18073795          1248               0
# 13          7769           631               0

# %%
assembly_stats[["Molecule", "Total Length"]]
# Out:
#          Molecule  Total Length
# 0             All     191142546
# 1    Chromosome_1      16497411
# 2    Chromosome_2      15265986
# 3    Chromosome_3      14796774
# 4    Chromosome_4      13375517
# 5    Chromosome_5      16473687
# 6    Chromosome_6      15273878
# 7    Chromosome_7      16452659
# 8    Chromosome_8      15676443
# 9    Chromosome_9      15806032
# 10  Chromosome_10      16296148
# 11  Chromosome_11      15796145
# 12  Chromosome_12      18073795
# 13       unplaced       1358071

# %%
nM = nucMit.merge(assembly_stats[["Molecule", "Total Length"]], left_on="CHR", right_on="Molecule")
nM
# Out:
#              GENE_ID            CHR     START       END  \
# 0    TCALIF_03216-PA   Chromosome_1  12748443  12752979
# 1    TCALIF_03266-PA   Chromosome_1  15238434  15249519
# 2    TCALIF_04664-PA   Chromosome_1   1943286   1946340
# 3    TCALIF_06837-PA   Chromosome_1   8307631   8309423
# 4    TCALIF_10240-PA   Chromosome_1   3819166   3819369
# ..               ...            ...       ...       ...
# 149  TCALIF_11595-PA  Chromosome_11   7589122   7591292
# 150  TCALIF_11597-PA  Chromosome_11   7632611   7634285
# 151  TCALIF_13636-PA  Chromosome_11   8752140   8752893
# 152  TCALIF_13826-PA  Chromosome_11  15703385  15709889
# 153  TCALIF_04550-PA  Chromosome_12   3878023   3878796
#
#                                               GENENAME MITO_CATEGORY  \
# 0    cox12 Cytochrome c oxidase subunit 6B (Schizos...       Comp-IV
# 1    MRPL27 39S ribosomal protein L27, mitochondria...           mRP
# 2    mRpL45 Probable 39S ribosomal protein L45, mit...           mRP
# 3    NDUFA6 NADH dehydrogenase [ubiquinone] 1 alpha...        Comp-I
# 4    Cox6c Cytochrome c oxidase subunit 6C (Mus mus...       Comp-IV
# ..                                                 ...           ...
# 149  Mrps2 28S ribosomal protein S2, mitochondrial ...           mRP
# 150  Mrpl48 39S ribosomal protein L48, mitochondria...           mRP
# 151  MRPS35 28S ribosomal protein S35, mitochondria...           mRP
# 152  MRPS30 28S ribosomal protein S30, mitochondria...           mRP
# 153  TFAM Transcription factor A, mitochondrial (Bo...          TFAM
#
#           Molecule  Total Length
# 0     Chromosome_1      16497411
# 1     Chromosome_1      16497411
# 2     Chromosome_1      16497411
# 3     Chromosome_1      16497411
# 4     Chromosome_1      16497411
# ..             ...           ...
# 149  Chromosome_11      15796145
# 150  Chromosome_11      15796145
# 151  Chromosome_11      15796145
# 152  Chromosome_11      15796145
# 153  Chromosome_12      18073795
#
# [154 rows x 8 columns]

# %%
# ok, need to scale genes on each chr to between 0 and 1.
# use start, end? Or calc "gene center pos" == halfway between start and end
# to plot, add (chrom# *10) to pos to get to correct location on linear genome axis running from 10->120.

# %%
nM["start_scaled"] = nM["START"]/nM["Total Length"]
nM["end_scaled"] = nM["END"]/nM["Total Length"]
nM["MIDDLE"] = nM["START"] + ((nM["END"] - nM["START"])/2) #
nM["middle_scaled"] = nM["MIDDLE"]/nM["Total Length"]
nM["chr_index"] = nM["CHR"].str.rsplit("_", expand=True)[1].astype('int64', copy=False)

# simplest plotting == scaled up by factor of 10!
# set position for gene on the linear chromosome scale running from 10-->120, with each chr taking 10
# e.g. chr 1 runs from 10-> 20; chr12 runs from 120-> 130
nM["chr_pos"] = (nM["middle_scaled"]*10) + (nM["chr_index"]*10)
nM["y_pos"] = 1
nM
# Out:
#              GENE_ID            CHR     START       END  \
# 0    TCALIF_03216-PA   Chromosome_1  12748443  12752979
# 1    TCALIF_03266-PA   Chromosome_1  15238434  15249519
# 2    TCALIF_04664-PA   Chromosome_1   1943286   1946340
# 3    TCALIF_06837-PA   Chromosome_1   8307631   8309423
# 4    TCALIF_10240-PA   Chromosome_1   3819166   3819369
# ..               ...            ...       ...       ...
# 149  TCALIF_11595-PA  Chromosome_11   7589122   7591292
# 150  TCALIF_11597-PA  Chromosome_11   7632611   7634285
# 151  TCALIF_13636-PA  Chromosome_11   8752140   8752893
# 152  TCALIF_13826-PA  Chromosome_11  15703385  15709889
# 153  TCALIF_04550-PA  Chromosome_12   3878023   3878796
#
#                                               GENENAME MITO_CATEGORY  \
# 0    cox12 Cytochrome c oxidase subunit 6B (Schizos...       Comp-IV
# 1    MRPL27 39S ribosomal protein L27, mitochondria...           mRP
# 2    mRpL45 Probable 39S ribosomal protein L45, mit...           mRP
# 3    NDUFA6 NADH dehydrogenase [ubiquinone] 1 alpha...        Comp-I
# 4    Cox6c Cytochrome c oxidase subunit 6C (Mus mus...       Comp-IV
# ..                                                 ...           ...
# 149  Mrps2 28S ribosomal protein S2, mitochondrial ...           mRP
# 150  Mrpl48 39S ribosomal protein L48, mitochondria...           mRP
# 151  MRPS35 28S ribosomal protein S35, mitochondria...           mRP
# 152  MRPS30 28S ribosomal protein S30, mitochondria...           mRP
# 153  TFAM Transcription factor A, mitochondrial (Bo...          TFAM
#
#           Molecule  Total Length  start_scaled  end_scaled      MIDDLE  \
# 0     Chromosome_1      16497411      0.772754    0.773029  12750711.0
# 1     Chromosome_1      16497411      0.923686    0.924358  15243976.5
# 2     Chromosome_1      16497411      0.117793    0.117979   1944813.0
# 3     Chromosome_1      16497411      0.503572    0.503680   8308527.0
# 4     Chromosome_1      16497411      0.231501    0.231513   3819267.5
# ..             ...           ...           ...         ...         ...
# 149  Chromosome_11      15796145      0.480441    0.480579   7590207.0
# 150  Chromosome_11      15796145      0.483195    0.483301   7633448.0
# 151  Chromosome_11      15796145      0.554068    0.554116   8752516.5
# 152  Chromosome_11      15796145      0.994128    0.994539  15706637.0
# 153  Chromosome_12      18073795      0.214566    0.214609   3878409.5
#
#      middle_scaled  chr_index     chr_pos  y_pos
# 0         0.772892          1   17.728916      1
# 1         0.924022          1   19.240224      1
# 2         0.117886          1   11.178860      1
# 3         0.503626          1   15.036261      1
# 4         0.231507          1   12.315071      1
# ..             ...        ...         ...    ...
# 149       0.480510         11  114.805101      1
# 150       0.483248         11  114.832475      1
# 151       0.554092         11  115.540919      1
# 152       0.994334         11  119.943336      1
# 153       0.214587         12  122.145874      1
#
# [154 rows x 15 columns]

# %%
# Create figure and axes
fig, ax = plt.subplots(1, figsize=(15, 1))


chr_dividers = np.arange(20, 130, 10)
ax.axhline(y=1, xmin=0, xmax=130, color="black")
ax.vlines(chr_dividers, ymin=-1, ymax=3, color="black", linewidth=1)
ax.plot(nM["chr_pos"], nM["y_pos"], marker='o', color = 'black', markerfacecolor='white')#ms=6,lw=1,, markeredgewidth=1)#markerfacecolor='white',

lims = ax.get_ylim()
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.tick_params(tick1On=False, tick2On=False)
ax.axes.xaxis.set_ticks([])
ax.axes.yaxis.set_ticks([])
ax.set_xlim(10,130)
plt.show()
#fig.savefig("mito-gene-locations.tg-genome2.1.circle.png",bbox_inches='tight')
fig.savefig("mito-gene-locations.tg-genome2.1.circle.pdf",bbox_inches='tight')
plt.close()

# %%
# Create figure and axes

fig, ax = plt.subplots(1, figsize=(15, 1))

chr_dividers = np.arange(10, 140, 10)
ax.axhline(y=1, xmin=0, xmax=130, color="black")
ax.vlines(chr_dividers, ymin=-1, ymax=3, color="black", linewidth=1)
ax.plot(nM["chr_pos"], nM["y_pos"], marker='o', color = 'black', markerfacecolor='white')#ms=6,lw=1,, markeredgewidth=1)#markerfacecolor='white',

lims = ax.get_ylim()
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.tick_params(tick1On=False, tick2On=False)
ax.axes.xaxis.set_ticks([])
ax.axes.yaxis.set_ticks([])
ax.set_xlim(9.9,130.101)
plt.show()
#fig.savefig("mito-gene-locations.tg-genome2.1.circle2.png",bbox_inches='tight')
fig.savefig("mito-gene-locations.tg-genome2.1.circle2.pdf",bbox_inches='tight')
plt.close()

# %%
# Create figure and axes
fig, ax = plt.subplots(1, figsize=(15, 1))

#ax.axhline(y=3, xmin=1, xmax=130, color="black")
ax.axhline(y=1, xmin=0, xmax=130, color="black")

chr_dividers = np.arange(20, 130, 10)
ax.vlines(chr_dividers, ymin=-1, ymax=3, color="black", linewidth=1)
ax.plot(nM["chr_pos"], nM["y_pos"], marker="|", color = 'black', ms=15)#, markerfacecolor='white')#, markerfacecolor='white')#ms=6,lw=1,, markeredgewidth=1)#markerfacecolor='white',


lims = ax.get_ylim()
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.tick_params(tick1On=False, tick2On=False)
ax.axes.xaxis.set_ticks([])
ax.axes.yaxis.set_ticks([])
ax.set_xlim(10,130)
plt.show()
#fig.savefig("mito-gene-locations.tg-genome2.1.vline.png",bbox_inches='tight')
fig.savefig("mito-gene-locations.tg-genome2.1.vline.pdf",bbox_inches='tight')
plt.close()

# %%
# Create figure and axes
fig, ax = plt.subplots(1, figsize=(15, 1))

#ax.axhline(y=3, xmin=1, xmax=130, color="black")
ax.axhline(y=1, xmin=0, xmax=130, color="black")

chr_dividers = np.arange(10, 140, 10)
ax.vlines(chr_dividers, ymin=-1, ymax=3, color="black", linewidth=1)
ax.plot(nM["chr_pos"], nM["y_pos"], marker="|", color = 'black', ms=15)#, markerfacecolor='white')#, markerfacecolor='white')#ms=6,lw=1,, markeredgewidth=1)#markerfacecolor='white',


lims = ax.get_ylim()
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.tick_params(tick1On=False, tick2On=False)
ax.axes.xaxis.set_ticks([])
ax.axes.yaxis.set_ticks([])
ax.set_xlim(9.9,130.101)
plt.show()
#fig.savefig("mito-gene-locations.tg-genome2.1.vline2.png",bbox_inches='tight')
fig.savefig("mito-gene-locations.tg-genome2.1.vline2.pdf",bbox_inches='tight')
plt.close()

# %%
# spot check locations with the gene info for some of the chromosomes (below)

# %%
nM["CHR"] == "Chromosome_1"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# Name: CHR, Length: 154, dtype: bool

# %%
nM[nM["CHR"] == "Chromosome_12"]
# Out:
#              GENE_ID            CHR    START      END  \
# 153  TCALIF_04550-PA  Chromosome_12  3878023  3878796
#
#                                               GENENAME MITO_CATEGORY  \
# 153  TFAM Transcription factor A, mitochondrial (Bo...          TFAM
#
#           Molecule  Total Length  start_scaled  end_scaled     MIDDLE  \
# 153  Chromosome_12      18073795      0.214566    0.214609  3878409.5
#
#      middle_scaled  chr_index     chr_pos  y_pos
# 153       0.214587         12  122.145874      1

# %%
nM[nM["CHR"] == "Chromosome_11"]
# Out:
#              GENE_ID            CHR     START       END  \
# 143  TCALIF_01724-PA  Chromosome_11   9619417   9624033
# 144  TCALIF_04256-PA  Chromosome_11   7125187   7126807
# 145  TCALIF_06458-PA  Chromosome_11   9224849   9225472
# 146  TCALIF_06478-PA  Chromosome_11   9147839   9150648
# 147  TCALIF_08515-PA  Chromosome_11  13296998  13299829
# 148  TCALIF_11057-PA  Chromosome_11    745080    754881
# 149  TCALIF_11595-PA  Chromosome_11   7589122   7591292
# 150  TCALIF_11597-PA  Chromosome_11   7632611   7634285
# 151  TCALIF_13636-PA  Chromosome_11   8752140   8752893
# 152  TCALIF_13826-PA  Chromosome_11  15703385  15709889
#
#                                               GENENAME MITO_CATEGORY  \
# 143  sdha Succinate dehydrogenase [ubiquinone] flav...       Comp-II
# 144  ATP5L ATP synthase subunit g, mitochondrial (H...        Comp-V
# 145  mRpL41 39S ribosomal protein L41, mitochondria...           mRP
# 146  Ndufs2 NADH dehydrogenase [ubiquinone] iron-su...        Comp-I
# 147  ATPsyn-Cf6 ATP synthase-coupling factor 6, mit...        Comp-V
# 148  Mrpl40 39S ribosomal protein L40, mitochondria...           mRP
# 149  Mrps2 28S ribosomal protein S2, mitochondrial ...           mRP
# 150  Mrpl48 39S ribosomal protein L48, mitochondria...           mRP
# 151  MRPS35 28S ribosomal protein S35, mitochondria...           mRP
# 152  MRPS30 28S ribosomal protein S30, mitochondria...           mRP
#
#           Molecule  Total Length  start_scaled  end_scaled      MIDDLE  \
# 143  Chromosome_11      15796145      0.608972    0.609265   9621725.0
# 144  Chromosome_11      15796145      0.451071    0.451174   7125997.0
# 145  Chromosome_11      15796145      0.583994    0.584033   9225160.5
# 146  Chromosome_11      15796145      0.579118    0.579296   9149243.5
# 147  Chromosome_11      15796145      0.841788    0.841967  13298413.5
# 148  Chromosome_11      15796145      0.047168    0.047789    749980.5
# 149  Chromosome_11      15796145      0.480441    0.480579   7590207.0
# 150  Chromosome_11      15796145      0.483195    0.483301   7633448.0
# 151  Chromosome_11      15796145      0.554068    0.554116   8752516.5
# 152  Chromosome_11      15796145      0.994128    0.994539  15706637.0
#
#      middle_scaled  chr_index     chr_pos  y_pos
# 143       0.609119         11  116.091186      1
# 144       0.451123         11  114.511225      1
# 145       0.584013         11  115.840134      1
# 146       0.579207         11  115.792074      1
# 147       0.841877         11  118.418771      1
# 148       0.047479         11  110.474787      1
# 149       0.480510         11  114.805101      1
# 150       0.483248         11  114.832475      1
# 151       0.554092         11  115.540919      1
# 152       0.994334         11  119.943336      1

# %%
nM[nM["CHR"] == "Chromosome_9"]
# Out:
#              GENE_ID           CHR     START       END  \
# 102  TCALIF_01170-PA  Chromosome_9   2359557   2375878
# 103  TCALIF_02369-PA  Chromosome_9   6114547   6116125
# 104  TCALIF_02370-PA  Chromosome_9   6117003   6118027
# 105  TCALIF_02796-PA  Chromosome_9   9794330   9796289
# 106  TCALIF_02874-PA  Chromosome_9   3165543   3167228
# 107  TCALIF_04272-PA  Chromosome_9    242865    247058
# 108  TCALIF_07328-PA  Chromosome_9   2516409   2518884
# 109  TCALIF_09288-PA  Chromosome_9   9127149   9130110
# 110  TCALIF_09297-PA  Chromosome_9   9043770   9044612
# 111  TCALIF_09299-PA  Chromosome_9   9025359   9032478
# 112  TCALIF_09677-PA  Chromosome_9   4324789   4325667
# 113  TCALIF_16413-PA  Chromosome_9  15454496  15459276
#
#                                               GENENAME  MITO_CATEGORY  \
# 102  MRPL44 39S ribosomal protein L44, mitochondria...            mRP
# 103  Ndufa4 NADH dehydrogenase [ubiquinone] 1 alpha...         Comp-I
# 104  Ndufs6 NADH dehydrogenase [ubiquinone] iron-su...         Comp-I
# 105  Guf1 Translation factor Guf1, mitochondrial (M...  Trans. Factor
# 106  ATPsyn-gamma ATP synthase subunit gamma, mitoc...         Comp-V
# 107  SPAC4G8.09 Putative leucine--tRNA ligase, mito...          mtARS
# 108  EARS2 Probable glutamate--tRNA ligase, mitocho...          mtARS
# 109  Mrpl2 39S ribosomal protein L2, mitochondrial ...            mRP
# 110  mRpL35 39S ribosomal protein L35, mitochondria...            mRP
# 111  MRPL28 39S ribosomal protein L28, mitochondria...            mRP
# 112  Mrpl30 39S ribosomal protein L30, mitochondria...            mRP
# 113  Cox6a1 Cytochrome c oxidase subunit 6A1, mitoc...        Comp-IV
#
#          Molecule  Total Length  start_scaled  end_scaled      MIDDLE  \
# 102  Chromosome_9      15806032      0.149282    0.150315   2367717.5
# 103  Chromosome_9      15806032      0.386849    0.386949   6115336.0
# 104  Chromosome_9      15806032      0.387004    0.387069   6117515.0
# 105  Chromosome_9      15806032      0.619658    0.619782   9795309.5
# 106  Chromosome_9      15806032      0.200274    0.200381   3166385.5
# 107  Chromosome_9      15806032      0.015365    0.015631    244961.5
# 108  Chromosome_9      15806032      0.159206    0.159362   2517646.5
# 109  Chromosome_9      15806032      0.577447    0.577635   9128629.5
# 110  Chromosome_9      15806032      0.572172    0.572225   9044191.0
# 111  Chromosome_9      15806032      0.571007    0.571458   9028918.5
# 112  Chromosome_9      15806032      0.273616    0.273672   4325228.0
# 113  Chromosome_9      15806032      0.977759    0.978062  15456886.0
#
#      middle_scaled  chr_index    chr_pos  y_pos
# 102       0.149798          9  91.497983      1
# 103       0.386899          9  93.868989      1
# 104       0.387037          9  93.870367      1
# 105       0.619720          9  96.197197      1
# 106       0.200328          9  92.003277      1
# 107       0.015498          9  90.154980      1
# 108       0.159284          9  91.592839      1
# 109       0.577541          9  95.775409      1
# 110       0.572199          9  95.721987      1
# 111       0.571232          9  95.712325      1
# 112       0.273644          9  92.736441      1
# 113       0.977911          9  99.779106      1
